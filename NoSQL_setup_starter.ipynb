# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `mongoimport --type json -d uk_food -c establishments --drop --jsonArray establishments.json`

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import re

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'autosaurus', 'classDB', 'config', 'epa', 'fruits_db', 'gardenDB', 'local', 'met', 'test', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# review the collections in our new database
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'The Bay',
#  'AddressLine2': 'St Margarets Bay',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'The Coastguard Inn',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4587.347174863443,
#  'FHRSID': 1034540,
#  'LocalAuthorityBusinessID': 'PI/000078691',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT15 6DY',
#  'RatingDate': '2022-08-17T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64bcc5821aa939103b3bc00e'),
#  'geocode': {'latitude': '51.152225', 'longitude': '1.387974'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1034540',
#             'rel': 'self'}],
# ...

# %%
# review a document in the establishments collection
document = db.establishments.find_one()
pprint(document)
# Out:
# {'AddressLine1': 'The Bay',
#  'AddressLine2': 'St Margarets Bay',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'The Coastguard Inn',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4587.347174863443,
#  'FHRSID': 1034540,
#  'LocalAuthorityBusinessID': 'PI/000078691',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT15 6DY',
#  'RatingDate': '2022-08-17T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64bcc5821aa939103b3bc00e'),
#  'geocode': {'latitude': '51.152225', 'longitude': '1.387974'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1034540',
#             'rel': 'self'}],
# ...

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
new_restaurant = {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant into the collection
new_document = establishments.insert_one(new_restaurant)

# %%
# Check that the new restaurant was inserted
new_document = establishments.find({"BusinessName": "Penang Flavours"})

# Print the content of each document
for document in new_document:
    print(document)
# Out:
# {'_id': ObjectId('64bcc84e95ff86e6c270bbdb'), 'BusinessName': 'Penang Flavours', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': '', 'AddressLine1': 'Penang Flavours', 'AddressLine2': '146A Plumstead Rd', 'AddressLine3': 'London', 'AddressLine4': '', 'PostCode': 'SE18 7DY', 'Phone': '', 'LocalAuthorityCode': '511', 'LocalAuthorityName': 'Greenwich', 'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk', 'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk', 'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''}, 'SchemeType': 'FHRS', 'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'}, 'RightToReply': '', 'Distance': 4623.972328074718, 'NewRatingPending': True}

# %%
#delete_duplicate = db.establishments.delete_many({"BusinessName": "Penang Flavours"})
#delete_duplicate

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
regex_pattern = re.compile(r"Restaurant/Cafe/Canteen", re.IGNORECASE)
query = {'BusinessType': {'$regex': regex_pattern}}
fields = {'BusinessTypeID', 'BusinessType'}


# Capture the results to a variable
results = establishments.find(query, fields)

# Pretty print the results
print("{:<40} {:<40}".format("BusinessTypeID", "BusinessType"))
print("="*65)

# Print the "BusinessName" and "BusinessType" fields in columns
for result in results:
    business_type_ID = result.get('BusinessTypeID', '')
    business_type = result.get('BusinessType', '')
    print("{:<40} {:<40}".format(business_type_ID, business_type))
# Out:
# BusinessTypeID                           BusinessType
# ...
# 1                                        Restaurant/Cafe/Canteen
# 1                                        Restaurant/Cafe/Canteen
# 1                                        Restaurant/Cafe/Canteen
# 1                                        Restaurant/Cafe/Canteen
# 1                                        Restaurant/Cafe/Canteen
# 1                                        Restaurant/Cafe/Canteen
# 1                                        Restaurant/Cafe/Canteen
# 1                                        Restaurant/Cafe/Canteen
# 1                                        Restaurant/Cafe/Canteen
# 1                                        Restaurant/Cafe/Canteen
# 1                                        Restaurant/Cafe/Canteen
# 1                                        Restaurant/Cafe/Canteen
# 1                                        Restaurant/Cafe/Canteen
# 1                                        Restaurant/Cafe/Canteen
# ...

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
establishments.update_one(new_restaurant, {'$set':{'BusinessTypeID': 1}})

# %%
# Confirm that the new restaurant was updated
new_establishments = db.establishments.find({"BusinessName": "Penang Flavours"})

# See the change in collection.
for document in new_establishments:
    pprint(document)
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64bcc84e95ff86e6c270bbdb'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
dover_docs = db.establishments.count_documents({'LocalAuthorityName': 'Dover'})
dover_docs
# Out:
# 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
#dover_docs = db.establishments.delete_many({"LocalAuthorityName": "Dover"})

# %%
# Check if any remaining documents include Dover
remaining_documents = db.establishments.find({"LocalAuthorityName": "Dover"})

pprint(remaining_documents)

# %%
# Check that other documents remain with 'find_one'
remaining_document = db.establishments.find_one()

if remaining_document:
    print("There are still remaining documents in the 'establishments' collection:")
    pprint(remaining_document)
else:
    print("No remaining documents in the 'establishments' collection.")
# Out:
# There are still remaining documents in the 'establishments' collection:
# {'AddressLine1': 'The Bay',
#  'AddressLine2': 'St Margarets Bay',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'The Coastguard Inn',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4587.347174863443,
#  'FHRSID': 1034540,
#  'LocalAuthorityBusinessID': 'PI/000078691',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT15 6DY',
#  'RatingDate': '2022-08-17T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64bcc5821aa939103b3bc00e'),
#  'geocode': {'latitude': '51.152225', 'longitude': '1.387974'},
# ...

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
db.establishments.update_many({},[{'$set': {"geocode.longitude": {'$toDouble': 
                "$geocode.longitude"},'geocode.latitude': {'$toDouble': "$geocode.latitude"}
            }}])

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])

# %%
# Change the data type from String to Integer for RatingValue
establishments.update_many({},[{'$set': {"RatingValue": {'$toInt': "$RatingValue"}}}])

# %%
# Check that the coordinates and rating value are now numbers
cordinates_display = db.establishments.find({}, {'_id': 1, 'geocode': 1}).limit(5)
for document in cordinates_display:
    pprint(document)

Rating_display = establishments.find({}, {'_id': 0, 'RatingValue': 1}).limit(5)
for document in Rating_display:
    pprint(document)
# Out:
# {'_id': ObjectId('64bcc5821aa939103b3bc00e'),
#  'geocode': {'latitude': 51.152225, 'longitude': 1.387974}}
# {'_id': ObjectId('64bcc5821aa939103b3bc00f'),
#  'geocode': {'latitude': 51.147379, 'longitude': 1.371115}}
# {'_id': ObjectId('64bcc5821aa939103b3bc010'),
#  'geocode': {'latitude': 51.150625, 'longitude': 1.378231}}
# {'_id': ObjectId('64bcc5821aa939103b3bc011'),
#  'geocode': {'latitude': 51.1787284, 'longitude': 1.4032986}}
# {'_id': ObjectId('64bcc5821aa939103b3bc012'),
#  'geocode': {'latitude': 51.1787284, 'longitude': 1.4032986}}
# {'RatingValue': 5}
# {'RatingValue': 5}
# {'RatingValue': 5}
# {'RatingValue': None}
# {'RatingValue': 5}
